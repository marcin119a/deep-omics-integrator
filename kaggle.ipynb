# %%
# Jeśli projekt jest w repozytorium GitHub, użyj:
# !git clone https://github.com/marcin119a/deep-omics-integrator.git
# %cd deep-omics-integrator

# Alternatywnie, jeśli masz prywatne repo, użyj token:
# !git clone https://YOUR_TOKEN@github.com/yourusername/deep-omics-integrator.git
# Out:
# Cloning into 'deep-omics-integrator'...
# remote: Enumerating objects: 63, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 63 (delta 30), reused 46 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (63/63), 36.31 KiB | 6.05 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
cd deep-omics-integrator
# Out:
# /kaggle/working/deep-omics-integrator

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 29.1 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 85.0 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 67.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 43.6 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 101.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 84.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.9/319.9 kB 20.9 MB/s eta 0:00:00
# ...
#   Created wheel for sorted_nearest: filename=sorted_nearest-0.0.41-cp311-cp311-linux_x86_64.whl size=6382527 sha256=89e3406c78177140f23dea8b7690a28c003913d6d081b0b9374bb6d43691dfa0
# ...

# %%
# !python train_exclude_pam50.py
# Out:
# 2025-11-23 23:10:42.763430: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763939442.943211     206 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763939442.994238     206 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
# Dane pobrane do: /kaggle/input/oncokb-cancer-gene-list
# ...
# Pobrano do data/hg38.fa.gz
# Unpacking hg38.fa.gz...
# Unpacked to data/hg38.fa
# Loading PAM50 barcodes from: data/pam50.csv
# ✓ Loaded 463 unique PAM50 patient barcodes to exclude
#
# Processing data and excluding PAM50 patients...
# ...

# %%
# !python evaluate_pam50.py --model saved_models/model_no_pam50_20251123_231256.keras
# Out:
# 2025-11-23 23:13:43.013463: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763939623.035783     816 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763939623.044289     816 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
# Dane pobrane do: /kaggle/input/oncokb-cancer-gene-list
# Plik hg38.fa już istnieje w data/hg38.fa
#
# Evaluating model on PAM50 subtypes: saved_models/model_no_pam50_20251123_231256.keras
# ...
# Loading PAM50 data from: data/pam50.csv
# ✓ Loaded 466 PAM50 samples
#   PAM50 subtype distribution:
# PAM50
# Basal      81
# Her2       53
# ...
